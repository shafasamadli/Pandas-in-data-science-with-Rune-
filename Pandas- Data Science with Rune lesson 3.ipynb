# %% [markdown]
# # Data science with Pandas

# %%
import pandas as pd

# %% [markdown]
# pd.read_csv(filename, parse_dates, index_col)
# filename: The path to the filename
# parse_dates=True: If True -> try parsing the index (default False)
# index_col=0: Set the index to be column 0

# %% [raw]
# Note: to download files -> go to jupyter page, click upload, select file and copy its link

# %%
#index_col=0 indexleri yox edir 
data = pd.read_csv('C:/Users/ACER/OneDrive - Azerbaijan State Oil and Industry University/Desktop/Data Science with Rune/files/aapl.csv',parse_dates=True,index_col=0)
data
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2021-11-08  151.570007  150.160004  151.410004  150.440002   55020900.0
# 2021-11-09  151.429993  150.059998  150.199997  150.809998   56787900.0
# 2021-11-10  150.130005  147.850006  150.020004  147.919998   65187100.0
# 2021-11-11  149.429993  147.679993  148.960007  147.869995   41000000.0
# 2021-11-12  150.399994  147.479996  148.429993  149.990005   63632600.0
#
#              Adj Close
# Date
# 2020-01-02   73.988464
# 2020-01-03   73.269150
# ...

# %%
# after importing and reading data check it 
data.head(10)
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  73.988464
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.269150
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.852982
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.505653
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.688080
# 2020-01-09  77.607498  76.550003  76.809998  77.407501  170108400.0  76.274513
# 2020-01-10  78.167503  77.062500  77.650002  77.582497  140644800.0  76.446938
# 2020-01-13  79.267502  77.787498  77.910004  79.239998  121532000.0  78.080177
# 2020-01-14  79.392502  78.042503  79.175003  78.169998  161954400.0  77.025856
# 2020-01-15  78.875000  77.387497  77.962502  77.834999  121923600.0  76.695763

# %%
# indexleri yeni 0,1,2,3,... seklinde yox etdikde burada indexleme datelere gore olur
data.index
#  dtype='datetime64[ns]' -> data type'in string deyil date time oldugunu gosterir
# Out:
# DatetimeIndex(['2020-01-02', '2020-01-03', '2020-01-06', '2020-01-07',
#                '2020-01-08', '2020-01-09', '2020-01-10', '2020-01-13',
#                '2020-01-14', '2020-01-15',
#                ...
#                '2021-11-01', '2021-11-02', '2021-11-03', '2021-11-04',
#                '2021-11-05', '2021-11-08', '2021-11-09', '2021-11-10',
#                '2021-11-11', '2021-11-12'],
#               dtype='datetime64[ns]', name='Date', length=472, freq=None)

# %%
# data setde olan sutunlari qaytarir 
data.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
# her bir sutunun data type'na baxmaq 
data.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %% [raw]
# Important note: data type float olanda yoxlamadan avtomatik olaraq missing value olmadigini bilirik cunki missing values float data typeda gosterile bilmez

# %%
data.isnull()
# Out:
#              High    Low   Open  Close  Volume  Adj Close
# Date
# 2020-01-02  False  False  False  False   False      False
# 2020-01-03  False  False  False  False   False      False
# 2020-01-06  False  False  False  False   False      False
# 2020-01-07  False  False  False  False   False      False
# 2020-01-08  False  False  False  False   False      False
# ...           ...    ...    ...    ...     ...        ...
# 2021-11-08  False  False  False  False   False      False
# 2021-11-09  False  False  False  False   False      False
# 2021-11-10  False  False  False  False   False      False
# 2021-11-11  False  False  False  False   False      False
# 2021-11-12  False  False  False  False   False      False
#
# [472 rows x 6 columns]

# %%
data.isna()
# Out:
#              High    Low   Open  Close  Volume  Adj Close
# Date
# 2020-01-02  False  False  False  False   False      False
# 2020-01-03  False  False  False  False   False      False
# 2020-01-06  False  False  False  False   False      False
# 2020-01-07  False  False  False  False   False      False
# 2020-01-08  False  False  False  False   False      False
# ...           ...    ...    ...    ...     ...        ...
# 2021-11-08  False  False  False  False   False      False
# 2021-11-09  False  False  False  False   False      False
# 2021-11-10  False  False  False  False   False      False
# 2021-11-11  False  False  False  False   False      False
# 2021-11-12  False  False  False  False   False      False
#
# [472 rows x 6 columns]

# %%
# datada nece row oldugunu gosterir 
len(data)
# Out:
# 472

# %%
# row, column
data.shape
# Out:
# (472, 6)

# %%
# Slicing in pandas series
# output look like data frame
data['High']
# Out:
# Date
# 2020-01-02     75.150002
# 2020-01-03     75.144997
# 2020-01-06     74.989998
# 2020-01-07     75.224998
# 2020-01-08     76.110001
#                  ...
# 2021-11-08    151.570007
# 2021-11-09    151.429993
# 2021-11-10    150.130005
# 2021-11-11    149.429993
# 2021-11-12    150.399994
# Name: High, Length: 472, dtype: float64

# %%
# it is important to write [[]] if we write one of them we incur error
# result will seem as data series
data[['Open','Close']]
# Out:
#                   Open       Close
# Date
# 2020-01-02   74.059998   75.087502
# 2020-01-03   74.287498   74.357498
# 2020-01-06   73.447502   74.949997
# 2020-01-07   74.959999   74.597504
# 2020-01-08   74.290001   75.797501
# ...                ...         ...
# 2021-11-08  151.410004  150.440002
# 2021-11-09  150.199997  150.809998
# 2021-11-10  150.020004  147.919998
# 2021-11-11  148.960007  147.869995
# 2021-11-12  148.429993  149.990005
#
# [472 rows x 2 columns]

# %%
# getting data with using specific location
data.loc['2020-01-08':'2020-01-18'] # both endpoints are including
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.688080
# 2020-01-09  77.607498  76.550003  76.809998  77.407501  170108400.0  76.274513
# 2020-01-10  78.167503  77.062500  77.650002  77.582497  140644800.0  76.446938
# 2020-01-13  79.267502  77.787498  77.910004  79.239998  121532000.0  78.080177
# 2020-01-14  79.392502  78.042503  79.175003  78.169998  161954400.0  77.025856
# 2020-01-15  78.875000  77.387497  77.962502  77.834999  121923600.0  76.695763
# 2020-01-16  78.925003  78.022499  78.397499  78.809998  108829200.0  77.656494
# 2020-01-17  79.684998  78.750000  79.067497  79.682503  137816400.0  78.516228

# %%
# Sadece 2020 yanvar ayinda olan datalari gormek ucun
data.loc['2020-01']
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  73.988464
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.269150
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.852982
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.505653
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.688080
# 2020-01-09  77.607498  76.550003  76.809998  77.407501  170108400.0  76.274513
# 2020-01-10  78.167503  77.062500  77.650002  77.582497  140644800.0  76.446938
# 2020-01-13  79.267502  77.787498  77.910004  79.239998  121532000.0  78.080177
# 2020-01-14  79.392502  78.042503  79.175003  78.169998  161954400.0  77.025856
# 2020-01-15  78.875000  77.387497  77.962502  77.834999  121923600.0  76.695763
# 2020-01-16  78.925003  78.022499  78.397499  78.809998  108829200.0  77.656494
# ...

# %%
data.loc['2020':'2021']
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2021-11-08  151.570007  150.160004  151.410004  150.440002   55020900.0
# 2021-11-09  151.429993  150.059998  150.199997  150.809998   56787900.0
# 2021-11-10  150.130005  147.850006  150.020004  147.919998   65187100.0
# 2021-11-11  149.429993  147.679993  148.960007  147.869995   41000000.0
# 2021-11-12  150.399994  147.479996  148.429993  149.990005   63632600.0
#
#              Adj Close
# Date
# 2020-01-02   73.988464
# 2020-01-03   73.269150
# ...

# %%
# We can also use indexes to get specific group of data 
data.iloc[100:110] # first number including, the second number excluding
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-05-27  79.677498  78.272499  79.035004  79.527496  112945200.0  78.762093
# 2020-05-28  80.860001  78.907501  79.192497  79.562500  133560800.0  78.796753
# 2020-05-29  80.287498  79.117500  79.812500  79.485001  153532400.0  78.720016
# 2020-06-01  80.587502  79.302498  79.437500  80.462502   80791200.0  79.688103
# 2020-06-02  80.860001  79.732498  80.187500  80.834999   87642800.0  80.057014
# 2020-06-03  81.550003  80.574997  81.165001  81.279999  104491200.0  80.497726
# 2020-06-04  81.404999  80.195000  81.097504  80.580002   87560400.0  79.804474
# 2020-06-05  82.937500  80.807503  80.837502  82.875000  137250400.0  82.077377
# 2020-06-08  83.400002  81.830002  82.562500  83.364998   95654400.0  82.562653
# 2020-06-09  86.402496  83.002502  83.035004  85.997498  147712400.0  85.169823

# %%
# to deal with aritmethic operations in pandas 
# we can calculate them along all elements of each column 
data['High'] - data['Low']
# Out:
# Date
# 2020-01-02    1.352501
# 2020-01-03    1.019997
# 2020-01-06    1.802498
# 2020-01-07    0.854996
# 2020-01-08    1.820000
#                 ...
# 2021-11-08    1.410004
# 2021-11-09    1.369995
# 2021-11-10    2.279999
# 2021-11-11    1.750000
# 2021-11-12    2.919998
# Length: 472, dtype: float64

# %%
data['Open'] + data['Close']
# Out:
# Date
# 2020-01-02    149.147499
# 2020-01-03    148.644997
# 2020-01-06    148.397499
# 2020-01-07    149.557503
# 2020-01-08    150.087502
#                  ...
# 2021-11-08    301.850006
# 2021-11-09    301.009995
# 2021-11-10    297.940002
# 2021-11-11    296.830002
# 2021-11-12    298.419998
# Length: 472, dtype: float64

# %%
# Hesablamalar apardiqdan sonra onu yeni sutuna yazib data sete elave etmek ucun
data['Data_new'] = data['Low'] - data['Close']

# %%
data
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2021-11-08  151.570007  150.160004  151.410004  150.440002   55020900.0
# 2021-11-09  151.429993  150.059998  150.199997  150.809998   56787900.0
# 2021-11-10  150.130005  147.850006  150.020004  147.919998   65187100.0
# 2021-11-11  149.429993  147.679993  148.960007  147.869995   41000000.0
# 2021-11-12  150.399994  147.479996  148.429993  149.990005   63632600.0
#
#              Adj Close  Data_new
# Date
# 2020-01-02   73.988464 -1.290001
# ...

# %% [raw]
# SELECT VALUES

# %%
# select values, result will be boolean
data['Data_new'] > 1
# Out:
# Date
# 2020-01-02    False
# 2020-01-03    False
# 2020-01-06    False
# 2020-01-07    False
# 2020-01-08    False
#               ...
# 2021-11-08    False
# 2021-11-09    False
# 2021-11-10    False
# 2021-11-11    False
# 2021-11-12    False
# Name: Data_new, Length: 472, dtype: bool

# %%
# xususile hansi deyerlerin 1-den kicik oldugunu gormek ucun 
data[data['Data_new'] < 1]
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2021-11-08  151.570007  150.160004  151.410004  150.440002   55020900.0
# 2021-11-09  151.429993  150.059998  150.199997  150.809998   56787900.0
# 2021-11-10  150.130005  147.850006  150.020004  147.919998   65187100.0
# 2021-11-11  149.429993  147.679993  148.960007  147.869995   41000000.0
# 2021-11-12  150.399994  147.479996  148.429993  149.990005   63632600.0
#
#              Adj Close  Data_new
# Date
# 2020-01-02   73.988464 -1.290001
# ...

# %%
# Categorize and group by 
# In this code part we just create new column and give boolean values to this column 
# Burada sadece dataya yeni bir column elave etdi ve data_new setrinde olan datalara sert verib onun esasinda yeni column(categorynin) icini doldurmus oldu
data['Category'] = data['Data_new'] > -0.5
data
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2021-11-08  151.570007  150.160004  151.410004  150.440002   55020900.0
# 2021-11-09  151.429993  150.059998  150.199997  150.809998   56787900.0
# 2021-11-10  150.130005  147.850006  150.020004  147.919998   65187100.0
# 2021-11-11  149.429993  147.679993  148.960007  147.869995   41000000.0
# 2021-11-12  150.399994  147.479996  148.429993  149.990005   63632600.0
#
#              Adj Close  Data_new  Category
# Date
# 2020-01-02   73.988464 -1.290001     False
# ...

# %%
# Burada ise category columnunu mean deyerlerine gore qruplasdir dedim yeni datada false deyerler olanlarin(hansiki sert vermisdik ki data_new columnu -0.5den boyuk olsun) butun columnlar uzre ededi ortasi yeni mean deyerini hesablayib yazir, true deyerler ucun de eyni processi heyata kecirir
data.groupby('Category').mean()
# Out:
#                 High         Low        Open       Close        Volume  \
# Category
# False     116.349212  113.557507  114.794255  115.374162  1.270804e+08
# True      114.611541  112.112458  113.814688  112.355292  1.201014e+08
#
#            Adj Close  Data_new
# Category
# False     114.691170 -1.816655
# True      111.699569 -0.242834

# %%
data['Category'].value_counts()
# Out:
# False    352
# True     120
# Name: Category, dtype: int64

# %%
(data['Data_new'] > -1).value_counts()
# Out:
# False    257
# True     215
# Name: Data_new, dtype: int64

# %% [markdown]
# # Project to improve knowledge in pandas

# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/ACER/OneDrive - Azerbaijan State Oil and Industry University\Desktop\Data Science with Rune/files/population.csv')
# ,index_col=0
data
# Out:
#    Country  Year  Population
# 0  Denmark  2000         5.3
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8
# 3   Sweden  2000         8.8
# 4   Sweden  2010         9.3
# 5   Sweden  2020        10.2

# %%
data.head()
# Out:
#    Country  Year  Population
# 0  Denmark  2000         5.3
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8
# 3   Sweden  2000         8.8
# 4   Sweden  2010         9.3

# %%
# indexi datani yukeleyerken index_col = 0 yazaraq datadan xaric etmek olur

# %%
data.dtypes
# Out:
# Country        object
# Year            int64
# Population    float64
# dtype: object

# %%
data['Population'].max()
# Out:
# 10.2

# %%
data['Population'].min()
# Out:
# 5.3

# %%
data['Population'].describe()
# Out:
# count     6.000000
# mean      7.483333
# std       2.188531
# min       5.300000
# 25%       5.575000
# 50%       7.300000
# 75%       9.175000
# max      10.200000
# Name: Population, dtype: float64

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Population'], dtype='object')

# %%
data.values
# Out:
# array([['Denmark', 2000, 5.3],
#        ['Denmark', 2010, 5.5],
#        ['Denmark', 2020, 5.8],
#        ['Sweden', 2000, 8.8],
#        ['Sweden', 2010, 9.3],
#        ['Sweden', 2020, 10.2]], dtype=object)

# %%
# In some cases we need to expand or making smaller our values, here we can use scaleing
# data['Population']= data['Population']*1000
data
# Out:
#    Country  Year  Population
# 0  Denmark  2000         5.3
# 1  Denmark  2010         5.5
# 2  Denmark  2020         5.8
# 3   Sweden  2000         8.8
# 4   Sweden  2010         9.3
# 5   Sweden  2020        10.2

# %% [raw]
# # Also we can remain stable our first view of data and add new column to show scaled values
# data['Scaled_population']= data['Population']*1000
# data

# %%
# Also we can remain stable our first view of data and add new column to show scaled values
data['Scaled_population']= data['Population']*1000
data
# Out:
#    Country  Year  Population  Scaled_population
# 0  Denmark  2000         5.3             5300.0
# 1  Denmark  2010         5.5             5500.0
# 2  Denmark  2020         5.8             5800.0
# 3   Sweden  2000         8.8             8800.0
# 4   Sweden  2010         9.3             9300.0
# 5   Sweden  2020        10.2            10200.0

# %%
import matplotlib as plt
# %matplotlib inline
data['Population'].plot.hist(figsize=(15,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Population'].plot()
# Out:
# <AxesSubplot:>

# %% [raw]
# # Calculate mean population for each country
# data.groupby('Country').mean()

# %%
# Calculate mean population for each country
data.groupby('Country').mean()
# Out:
#            Year  Population  Scaled_population
# Country
# Denmark  2010.0    5.533333        5533.333333
# Sweden   2010.0    9.433333        9433.333333

# %%
# Calculate standard deviation for each country
data.groupby('Country').std()
# Out:
#          Year  Population  Scaled_population
# Country
# Denmark  10.0    0.251661         251.661148
# Sweden   10.0    0.709460         709.459888

# %%
# Categorize
data['New_column'] = data['Population'] > 6 # boolean values
data[data['New_column']] # populationu 6-dan boyuk olanlari gormek ucun
# Out:
#   Country  Year  Population  Scaled_population  New_column
# 3  Sweden  2000         8.8             8800.0        True
# 4  Sweden  2010         9.3             9300.0        True
# 5  Sweden  2020        10.2            10200.0        True

# %%
data.groupby('New_column').median()
# Out:
#               Year  Population  Scaled_population
# New_column
# False       2010.0         5.5             5500.0
# True        2010.0         9.3             9300.0

# %%
data.dtypes
# Out:
# Country               object
# Year                   int64
# Population           float64
# Scaled_population    float64
# New_column              bool
# dtype: object

# %% [raw]
# Country columnda olan Denmark deyerini qisaca DNK olsun istedikde:
# data['Country']= data['Country'].str.replace('Denmark', 'DNK')

# %%
data['Country']= data['Country'].str.replace('Denmark', 'DNK')
data
# Out:
#   Country  Year  Population  Scaled_population  New_column
# 0     DNK  2000         5.3             5300.0       False
# 1     DNK  2010         5.5             5500.0       False
# 2     DNK  2020         5.8             5800.0       False
# 3  Sweden  2000         8.8             8800.0        True
# 4  Sweden  2010         9.3             9300.0        True
# 5  Sweden  2020        10.2            10200.0        True

# %% [raw]
# Change type of 'date' to datetime
# type'ni deyiseceyimiz columnun adi(data['Year']) = pd.to_datetime(type'ni deyiseceyimiz columnun adi(data['Year']),format='%Y')
#
# data['Year'] = pd.to_datetime(data['Year'], format = '%Y')

# %%
# change type of year values to datetime
data['Year'] = pd.to_datetime(data['Year'], format = '%Y')
data
# Out:
#   Country       Year  Population  Scaled_population  New_column
# 0     DNK 2000-01-01         5.3             5300.0       False
# 1     DNK 2010-01-01         5.5             5500.0       False
# 2     DNK 2020-01-01         5.8             5800.0       False
# 3  Sweden 2000-01-01         8.8             8800.0        True
# 4  Sweden 2010-01-01         9.3             9300.0        True
# 5  Sweden 2020-01-01        10.2            10200.0        True

# %%
data['Country']
# Out:
# 0       DNK
# 1       DNK
# 2       DNK
# 3    Sweden
# 4    Sweden
# 5    Sweden
# Name: Country, dtype: object

# %%
data[data['Population']>5.7]
# Out:
#   Country       Year  Population  Scaled_population  New_column
# 2     DNK 2020-01-01         5.8             5800.0       False
# 3  Sweden 2000-01-01         8.8             8800.0        True
# 4  Sweden 2010-01-01         9.3             9300.0        True
# 5  Sweden 2020-01-01        10.2            10200.0        True

# %%
data['Population']>5.7
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# Name: Population, dtype: bool

# %%
data.dtypes
# Out:
# Country                      object
# Year                 datetime64[ns]
# Population                  float64
# Scaled_population           float64
# New_column                     bool
# dtype: object
